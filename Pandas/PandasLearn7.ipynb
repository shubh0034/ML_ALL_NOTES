# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # String **Operations**

# %%
# what are vectorized operation
a=np.array([1,2,3,4])
a*4
# Out:
# array([ 4,  8, 12, 16])

# %%
# problem in vectorized operation in vanilla python
s=['cat','mat',None,'rat']
[i.startswith('c') for i in s]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1728560841.py in <cell line: 0>()
#       1 # problem in vectorized operation in vanilla python
#       2 s=['cat','mat',None,'rat']
# ----> 3 [i.startswith('c') for i in s]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
# how pandas solve this problem
# it is okk with none and also extremely fast and optimise
s=pd.Series(['cat','mat',None,'rat'])
s.str.startswith('c')
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
df=pd.read_csv('/content/titanic.csv')
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# lower/upper/Captilize/title
df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# len
df['Name'][df['Name'].str.len()==82]
# Out:
# 307    Penasco y Castellana, Mrs. Victor de Satode (M...
# Name: Name, dtype: object

# %%
# strip
df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# split
df['lastname']=df['Name'].str.split(',').str.get(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   lastname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
df[['title','firstName']]=df['Name'].str.split(',').str.get(1).str.strip().str.split(' ',n=1,expand=True)
df.head()
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Mlle.          2
# Major.         2
# Ms.            1
# Mme.           1
# Don.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
# replace
df['title']=df['title'].str.replace('Ms.','Miss.')
df['title']=df['title'].str.replace('Mlle.','Miss.')
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        185
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Major.         2
# Col.           2
# Don.           1
# Lady.          1
# Mme.           1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
# filtering
df[df['firstName'].str.startswith('A')]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 13            14         0       3         Andersson, Mr. Anders Johan
# 22            23         1       3         McGowan, Miss. Anna "Annie"
# 35            36         0       1      Holverson, Mr. Alexander Oskar
# 38            39         0       3  Vander Planke, Miss. Augusta Maria
# 61            62         1       1                 Icard, Miss. Amelie
# ..           ...       ...     ...                                 ...
# 842          843         1       1             Serepeca, Miss. Augusta
# 845          846         0       3                 Abbing, Mr. Anthony
# 866          867         1       2        Duran y More, Miss. Asuncion
# 875          876         1       3    Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3       Gustafsson, Mr. Alfred Ossian
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked  \
# ...

# %%
# isdigit/isalpha
df[df['title'].str.isdigit()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, lastname, title, firstName]
# Index: []

# %%
# contains
df[df['firstName'].str.contains('john',case=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# 550          551         1       1
# 563          564         0       3
# 572          573         1       1
# ...

# %%
# find lastname with start and end char vowel
df[df['firstName'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$')]
# .=firstchar AND $ = lastchar AND ^[^aeiouAEIOU]=not the written part
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 16            17         0       3                   Rice, Master. Eugene
# 38            39         0       3     Vander Planke, Miss. Augusta Maria
# 61            62         1       1                    Icard, Miss. Amelie
# 64            65         0       1                  Stewart, Mr. Albert A
# 68            69         1       3        Andersson, Miss. Erna Alexandra
# 80            81         0       3                   Waelens, Mr. Achille
# 106          107         1       3       Salkjelsvik, Miss. Anna Kristine
# 119          120         0       3      Andersson, Miss. Ellis Anna Maria
# 128          129         1       3                      Peter, Miss. Anna
# 135          136         0       2                     Richard, Mr. Emile
# 141          142         1       3               Nysten, Miss. Anna Sofia
# 152          153         0       3                       Meo, Mr. Alfonzo
# ...

# %%
# slicing
df['Name'].str[::-1]
# Out:
# 0                                sirraH newO .rM ,dnuarB
# 1      )reyahT sggirB ecnerolF( yeldarB nhoJ .srM ,sg...
# 2                                 aniaL .ssiM ,nenikkieH
# 3           )leeP yaM yliL( htaeH seuqcaJ .srM ,ellertuF
# 4                               yrneH mailliW .rM ,nellA
#                              ...
# 886                                sazouJ .veR ,alivtnoM
# 887                         htidE teragraM .ssiM ,maharG
# 888             "eirraC" neleH enirehtaC .ssiM ,notsnhoJ
# 889                                llewoH lraK .rM ,rheB
# 890                                  kcirtaP .rM ,yelooD
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# # TimeStamp **Object**

# %% [markdown]
# Time Straps reference particular moments in time (e.g. Oct 24th,2022 at 7:00pm)

# %%
# creating timestamp object
type(pd.Timestamp('2023/1/5'))
# same result for
# 2023-1-5
# 2023,1,5
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# only year
pd.Timestamp('2025')
# Out:
# Timestamp('2025-01-01 00:00:00')

# %%
# using text
pd.Timestamp('5th September 2025')
# Out:
# Timestamp('2025-09-05 00:00:00')

# %%
# providing time also
pd.Timestamp('5th September 2025 10:35am')
# Out:
# Timestamp('2025-09-05 10:35:00')

# %%
# using datetime object of python
import datetime as dt

# %%
x=pd.Timestamp(dt.datetime(2025,9,5,10,35))
x
# Out:
# Timestamp('2025-09-05 10:35:00')

# %%
# fetching attributes
x.year
x.month
x.day
x.hour
x.second
x.minute
# Out:
# 9

# %% [markdown]
# **Why Timestamp if datetime is there**
#
# becz datetime is slow

# %% [markdown]
# # **Datetimeindex Object**

# %%
# from string
type(pd.DatetimeIndex(['2023/1/1','2022/1/1','2021/1/1'])[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(pd.DatetimeIndex(['2023/1/1','2022/1/1','2021/1/1']))
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# using python datetime
pd.DatetimeIndex([dt.datetime(2025,2,1),dt.datetime(2024,1,2),dt.datetime(2023,3,2)])
# Out:
# DatetimeIndex(['2025-02-01', '2024-01-02', '2023-03-02'], dtype='datetime64[ns]', freq=None)

# %%
dt_index=pd.DatetimeIndex([pd.Timestamp(2025,2,1),pd.Timestamp(2024,1,2),pd.Timestamp(2023,3,2)])

# %%
pd.Series([1,2,3],index=dt_index)
# Out:
# 2025-02-01    1
# 2024-01-02    2
# 2023-03-02    3
# dtype: int64

# %% [markdown]
# # **Date Range Function**

# %%
# generate daily dates in a given range
pd.date_range(start='2025/9/1',end='2025/9,20',freq='D')
# Out:
# DatetimeIndex(['2025-09-01', '2025-09-02', '2025-09-03', '2025-09-04',
#                '2025-09-05', '2025-09-06', '2025-09-07', '2025-09-08',
#                '2025-09-09', '2025-09-10', '2025-09-11', '2025-09-12',
#                '2025-09-13', '2025-09-14', '2025-09-15', '2025-09-16',
#                '2025-09-17', '2025-09-18', '2025-09-19', '2025-09-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2025/9/1',end='2025/9,20',freq='B')
# Out:
# DatetimeIndex(['2025-09-01', '2025-09-02', '2025-09-03', '2025-09-04',
#                '2025-09-05', '2025-09-08', '2025-09-09', '2025-09-10',
#                '2025-09-11', '2025-09-12', '2025-09-15', '2025-09-16',
#                '2025-09-17', '2025-09-18', '2025-09-19'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start='2025/9/1',end='2025/9,20',freq='W')
# Out:
# DatetimeIndex(['2025-09-07', '2025-09-14'], dtype='datetime64[ns]', freq='W-SUN')

# %%
# har ghante ka
pd.date_range(start='2025/9/1',end='2025/9,20',freq='7h')
# Out:
# DatetimeIndex(['2025-09-01 00:00:00', '2025-09-01 07:00:00',
#                '2025-09-01 14:00:00', '2025-09-01 21:00:00',
#                '2025-09-02 04:00:00', '2025-09-02 11:00:00',
#                '2025-09-02 18:00:00', '2025-09-03 01:00:00',
#                '2025-09-03 08:00:00', '2025-09-03 15:00:00',
#                '2025-09-03 22:00:00', '2025-09-04 05:00:00',
#                '2025-09-04 12:00:00', '2025-09-04 19:00:00',
#                '2025-09-05 02:00:00', '2025-09-05 09:00:00',
#                '2025-09-05 16:00:00', '2025-09-05 23:00:00',
#                '2025-09-06 06:00:00', '2025-09-06 13:00:00',
#                '2025-09-06 20:00:00', '2025-09-07 03:00:00',
#                '2025-09-07 10:00:00', '2025-09-07 17:00:00',
#                '2025-09-08 00:00:00', '2025-09-08 07:00:00',
#                '2025-09-08 14:00:00', '2025-09-08 21:00:00',
#                '2025-09-09 04:00:00', '2025-09-09 11:00:00',
# ...

# %%
pd.date_range(start='2025/9/1',periods=70,freq='ME')
# Out:
# DatetimeIndex(['2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31',
#                '2026-01-31', '2026-02-28', '2026-03-31', '2026-04-30',
#                '2026-05-31', '2026-06-30', '2026-07-31', '2026-08-31',
#                '2026-09-30', '2026-10-31', '2026-11-30', '2026-12-31',
#                '2027-01-31', '2027-02-28', '2027-03-31', '2027-04-30',
#                '2027-05-31', '2027-06-30', '2027-07-31', '2027-08-31',
#                '2027-09-30', '2027-10-31', '2027-11-30', '2027-12-31',
#                '2028-01-31', '2028-02-29', '2028-03-31', '2028-04-30',
#                '2028-05-31', '2028-06-30', '2028-07-31', '2028-08-31',
#                '2028-09-30', '2028-10-31', '2028-11-30', '2028-12-31',
#                '2029-01-31', '2029-02-28', '2029-03-31', '2029-04-30',
#                '2029-05-31', '2029-06-30', '2029-07-31', '2029-08-31',
#                '2029-09-30', '2029-10-31', '2029-11-30', '2029-12-31',
# ...

# %% [markdown]
# # **to_datetime function**

# %%
# simple series example
s=pd.Series(['2021/1/1','2022/1/1','2023/1/1'])
pd.to_datetime(s).dt.day_name()
# Out:
# 0      Friday
# 1    Saturday
# 2      Sunday
# dtype: object

# %%
# with errors
s=pd.Series(['2021/1/1','2022/1/1','2023/130/1'])
pd.to_datetime(s,errors='coerce')
# Out:
# 0   2021-01-01
# 1   2022-01-01
# 2          NaT
# dtype: datetime64[ns]

# %%
df=pd.read_csv('/content/expense_data.csv')
df.shape
# Out:
# (277, 11)

# %%
df.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0     2022-03-02 10:11:00
# 1     2022-03-02 10:11:00
# 2     2022-03-01 19:50:00
# 3     2022-03-01 18:56:00
# 4     2022-03-01 18:22:00
#               ...
# 272   2021-11-22 14:16:00
# 273   2021-11-22 14:16:00
# 274   2021-11-21 17:07:00
# 275   2021-11-21 15:50:00
# 276   2021-11-21 13:30:00
# Name: Date, Length: 277, dtype: datetime64[ns]

# %%
df['Date'].dt.month_name()
# Out:
# 0         March
# 1         March
# 2         March
# 3         March
# 4         March
#          ...
# 272    November
# 273    November
# 274    November
# 275    November
# 276    November
# Name: Date, Length: 277, dtype: object

# %%
# plot graphs
import matplotlib.pyplot as plt

# %%
plt.plot(df['Date'],df['INR'])

# %%
# day name wise bar chart
df['day_name']=df['Date'].dt.day_name()

# %%
df.groupby('day_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>

# %%
df['month_name']=df['Date'].dt.month_name()

# %%
df.groupby('month_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month_name'>
