# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # *Series using read_csv*

# %%
pd.read_csv('/content/bollywood.csv')
# Out:
#      SlNo ReleaseDate                  MovieName ReleaseTime     Genre  \
# 0       1   18-Apr-14                    2States          LW   Romance
# 1       2    4-Jan-13                 TableNo.21           N  Thriller
# 2       3   18-Jul-14            AmitSahniKiList           N    Comedy
# 3       4    4-Jan-13            RajdhaniExpress           N     Drama
# 4       5    4-Jul-14                BobbyJasoos           N    Comedy
# ..    ...         ...                        ...         ...       ...
# 144   145   27-Feb-15            DumLagaKeHaisha           N    Comedy
# 145   146   13-Mar-15                       NH10           N  Thriller
# 146   147   20-Mar-15  DilliwaliZaalimGirlfriend           N    Comedy
# 147   148   20-Mar-15                   Hunterrr           N    Comedy
# 148   149   23-May-14              Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
# with one col
# subs=pd.read_csv('/content/bollywood.csv',squeeze=True) squeeze is removed from pandas 2.0
# pd.read_csv store data in dataframes

# %%
# it stores only one column
subs=pd.read_csv('/content/bollywood.csv',usecols=[2]).squeeze('columns')
# type(subs)
subs
# Out:
# 0                        2States
# 1                     TableNo.21
# 2                AmitSahniKiList
# 3                RajdhaniExpress
# 4                    BobbyJasoos
#                  ...
# 144              DumLagaKeHaisha
# 145                         NH10
# 146    DilliwaliZaalimGirlfriend
# 147                     Hunterrr
# 148                Kochadaiiyaan
# Name: MovieName, Length: 149, dtype: object

# %%
df=pd.read_csv('/content/bollywood.csv')
subs=pd.Series(df['Budget'].values,index=df['MovieName'].values,name='BudgetList')
subs
# Out:
# 2States                       36
# TableNo.21                    10
# AmitSahniKiList               10
# RajdhaniExpress                7
# BobbyJasoos                   18
#                             ...
# DumLagaKeHaisha               15
# NH10                          13
# DilliwaliZaalimGirlfriend     32
# Hunterrr                       5
# Kochadaiiyaan                150
# Name: BudgetList, Length: 149, dtype: int64

# %% [markdown]
# # ***Series Methods***

# %%
# head and tail
subs.head(3)#starting 5 by default
# Out:
# 2States                 36
# 3G                       5
# ABCD_AnyBodyCanDance    12
# Name: BudgetList, dtype: int64

# %%
subs.tail()#ending 5 by default
# Out:
# YehJawaaniHaiDeewani    70
# Youngistaan             26
# Zanjeer                 75
# Zid                     20
# ZillaGhaziabad          36
# Name: BudgetList, dtype: int64

# %%
# sample
subs.sample(4)#random movie dega
# Out:
# MumbaiMirror       4
# WarChhodNaYaar    14
# BombayTalkies      6
# Kaanchi           31
# Name: BudgetList, dtype: int64

# %%
# value_counts :- it count the no of values in the file
subs.value_counts()
# Out:
# BudgetList
# 10     12
# 15     10
# 5       9
# 30      9
# 12      9
# 35      8
# 50      7
# 40      5
# 24      5
# 25      4
# 20      4
# 4       4
# 18      4
# 27      3
# 7       3
# 60      3
# 2       3
# 16      3
# 75      3
# 11      3
# 36      2
# 22      2
# 100     2
# 31      2
# 21      2
# 85      2
# 90      2
# 6       2
# 8       2
# 33      1
# 28      1
# 125     1
# 48      1
# 9       1
# 3       1
# 120     1
# 42      1
# 45      1
# 70      1
# 19      1
# 26      1
# 140     1
# 29      1
# 115     1
# 14      1
# 23      1
# 13      1
# 32      1
# 150     1
# Name: count, dtype: int64

# %%
# sort values
subs.sort_values(ascending=False).head(1).index[0]
# inplace can change the original series
# Out:
# 'Kochadaiiyaan'

# %%
# sort_index
subs.sort_index(inplace=True)

# %%
subs#yaha pe inplace ne change kr diya h series ko
# Out:
# 2States                 36
# 3G                       5
# ABCD_AnyBodyCanDance    12
# Aashiqui2               12
# Aatma                    8
#                         ..
# YehJawaaniHaiDeewani    70
# Youngistaan             26
# Zanjeer                 75
# Zid                     20
# ZillaGhaziabad          36
# Name: BudgetList, Length: 149, dtype: int64

# %% [markdown]
# # **Series Maths Method**

# %%
# count
subs.count()#total no. of non missing values inside the series
# Out:
# np.int64(149)

# %%
# sum
subs.sum()
# Out:
# np.int64(4387)

# %%
# product
subs.product()
# Out:
# np.int64(0)

# %%
# mean/median/mode
subs.mean()
# Out:
# np.float64(29.44295302013423)

# %%
subs.mode()#here 0  is index and 10 is mode
# Out:
# 0    10
# Name: BudgetList, dtype: int64

# %%
subs.median()
# Out:
# 21.0

# %%
# std/var
subs.std()
# Out:
# 28.23798059312152

# %%
subs.var()
# Out:
# 797.3835479775075

# %%
# min/max
subs.min()
# Out:
# 2

# %%
subs.max()
# Out:
# 150

# %%
# describe
subs.describe()
# Out:
# count    149.000000
# mean      29.442953
# std       28.237981
# min        2.000000
# 25%       11.000000
# 50%       21.000000
# 75%       35.000000
# max      150.000000
# Name: BudgetList, dtype: float64

# %% [markdown]
# # ***Series indexing***

# %%
# integer indexing
x=pd.Series([12,13,14,15,35,46,57,58,79])
x[0]
# Out:
# np.int64(12)

# %%
# negative indexing
# x[-1] it will not work

# %%
subs[0]
# Out:
# /tmp/ipython-input-4014724879.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   subs[0]
# np.int64(36)

# %%
subs[-2]
# Out:
# /tmp/ipython-input-1572789583.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   subs[-2]
# np.int64(20)

# %%
subs["2States"]
# Out:
# np.int64(36)

# %%
# slicing
subs[5:16]
# Out:
# ActionJackson       90
# Alone               18
# AmitSahniKiList     10
# Aurangzeb           20
# B.A.Pass             2
# BaatBanGayi          4
# Baby                60
# Badlapur            23
# BajateyRaho          5
# Bandook              4
# BangBang           140
# Name: BudgetList, dtype: int64

# %%
# fancy indexing
subs[[1,3,6,7,10]]
# Out:
# /tmp/ipython-input-1372025220.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   subs[[1,3,6,7,10]]
# 3G                  5
# Aashiqui2          12
# Alone              18
# AmitSahniKiList    10
# BaatBanGayi         4
# Name: BudgetList, dtype: int64

# %% [markdown]
# # **Editing Series**

# %%
# using indexing
subs[1]=100
subs
# Out:
# /tmp/ipython-input-2682981719.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   subs[1]=100
# 2States                  36
# 3G                      100
# ABCD_AnyBodyCanDance     12
# Aashiqui2                12
# Aatma                     8
#                        ...
# YehJawaaniHaiDeewani     70
# Youngistaan              26
# Zanjeer                  75
# Zid                      20
# ZillaGhaziabad           36
# Name: BudgetList, Length: 149, dtype: int64

# %%
subs['pathan']=300#add in the end
subs
# Out:
# 2States                  36
# 3G                      100
# ABCD_AnyBodyCanDance     12
# Aashiqui2                12
# Aatma                     8
#                        ...
# Youngistaan              26
# Zanjeer                  75
# Zid                      20
# ZillaGhaziabad           36
# pathan                  300
# Name: BudgetList, Length: 150, dtype: int64

# %%
# slicing
subs[3:6]=25
subs
# Out:
# 2States                  36
# 3G                      100
# ABCD_AnyBodyCanDance     12
# Aashiqui2                25
# Aatma                    25
#                        ...
# Youngistaan              26
# Zanjeer                  75
# Zid                      20
# ZillaGhaziabad           36
# pathan                  300
# Name: BudgetList, Length: 150, dtype: int64

# %%
# using fancy indexing
subs[[2,1,15,149]]=0
subs
# Out:
# /tmp/ipython-input-798691947.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   subs[[2,1,15,149]]=0
# 2States                 36
# 3G                       0
# ABCD_AnyBodyCanDance     0
# Aashiqui2               25
# Aatma                   25
#                         ..
# Youngistaan             26
# Zanjeer                 75
# Zid                     20
# ZillaGhaziabad          36
# pathan                   0
# Name: BudgetList, Length: 150, dtype: int64

# %% [markdown]
# # **Series with Python Functionalities**

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 149
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
list(subs)
# Out:
# [36,
#  10,
#  10,
#  7,
#  18,
#  7,
#  30,
#  33,
#  31,
#  2,
#  28,
#  5,
#  35,
#  4,
#  60,
#  4,
#  60,
#  10,
#  15,
#  10,
#  10,
#  27,
#  50,
#  24,
#  48,
#  42,
#  125,
#  12,
#  12,
#  11,
#  12,
#  12,
#  21,
#  30,
#  30,
#  36,
#  50,
#  20,
#  30,
#  75,
#  15,
#  120,
#  12,
#  100,
#  5,
#  35,
#  5,
#  10,
#  8,
#  7,
#  16,
#  8,
#  40,
#  10,
#  50,
#  3,
#  15,
#  20,
#  15,
#  9,
#  2,
#  22,
#  24,
#  5,
#  12,
#  21,
#  12,
#  10,
#  45,
#  25,
#  6,
#  18,
#  16,
#  35,
#  24,
#  50,
#  20,
#  25,
#  90,
#  35,
#  15,
#  5,
#  70,
#  19,
#  24,
#  5,
#  26,
#  5,
#  20,
#  85,
#  35,
#  90,
#  140,
#  15,
#  24,
#  30,
#  85,
#  27,
#  10,
#  16,
#  30,
#  30,
#  31,
#  18,
#  2,
#  35,
#  22,
#  30,
#  15,
#  10,
#  27,
#  5,
#  15,
#  4,
#  29,
#  75,
#  100,
#  35,
#  50,
#  115,
#  10,
#  15,
#  12,
#  30,
#  50,
#  14,
#  4,
#  50,
#  6,
#  11,
#  75,
#  25,
#  35,
#  12,
#  40,
#  10,
#  40,
#  18,
#  60,
#  25,
#  11,
#  40,
#  40,
#  23,
#  15,
# ...

# %%
dict(subs)
# Out:
# {'2States': np.int64(36),
#  'TableNo.21': np.int64(10),
#  'AmitSahniKiList': np.int64(10),
#  'RajdhaniExpress': np.int64(7),
#  'BobbyJasoos': np.int64(18),
#  'Citylights': np.int64(7),
#  'Daawat-E-Ishq': np.int64(30),
#  'MatruKiBijleeKaMandola': np.int64(33),
#  'DedhIshqiya': np.int64(31),
#  'Gangoobai': np.int64(2),
#  'Dishkiyaoon': np.int64(28),
#  'Inkaar': np.int64(5),
#  'EkVillain': np.int64(35),
#  'MumbaiMirror': np.int64(4),
#  'Entertainment': np.int64(60),
#  'Bandook': np.int64(4),
#  'Race2': np.int64(60),
#  'Filmistaan': np.int64(10),
#  'FindingFanny': np.int64(15),
#  'Fugly': np.int64(10),
#  'David': np.int64(10),
#  'GulaabGang': np.int64(27),
#  'Gunday': np.int64(50),
#  'Haider': np.int64(24),
#  'HappyEnding': np.int64(48),
#  'Special26': np.int64(42),
#  'HappyNewYear': np.int64(125),
#  'ABCD_AnyBodyCanDance': np.int64(12),
#  'HateStory2': np.int64(12),
#  'HawaaHawaai': np.int64(11),
#  'Heartless': np.int64(12),
#  'Murder3': np.int64(12),
# ...

# %%
# membership operator
'2States' in subs # in operator works on index
# Out:
# True

# %%
36 in subs.values
# Out:
# True

# %%
# looping also works

# %%
# Arithmetic operators
100/subs
# Out:
# 2States                       2.777778
# TableNo.21                   10.000000
# AmitSahniKiList              10.000000
# RajdhaniExpress              14.285714
# BobbyJasoos                   5.555556
#                                ...
# DumLagaKeHaisha               6.666667
# NH10                          7.692308
# DilliwaliZaalimGirlfriend     3.125000
# Hunterrr                     20.000000
# Kochadaiiyaan                 0.666667
# Name: BudgetList, Length: 149, dtype: float64

# %%
# Relational Operators and boolean indexing
subs[subs>=50].size
# Out:
# 25

# %% [markdown]
# # **Ploting Graphs on Series**

# %%
subs.plot()
# Out:
# <Axes: >

# %%
subs.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='BudgetList'>

# %% [markdown]
# # **Extra Series Method**

# %%
# astype method
import sys
sys.getsizeof(subs)
# Out:
# 14270

# %%
sys.getsizeof(subs.astype('int32'))
# Out:
# 13674

# %%
# between
subs[subs.between(20,50)]
# Out:
# 2States                      36
# Daawat-E-Ishq                30
# MatruKiBijleeKaMandola       33
# DedhIshqiya                  31
# Dishkiyaoon                  28
#                              ..
# Hawaizaada                   25
# Shamitabh                    40
# Roy                          40
# Badlapur                     23
# DilliwaliZaalimGirlfriend    32
# Name: BudgetList, Length: 62, dtype: int64

# %%
# clip
subs.clip(30,50)
# Out:
# 2States                      36
# TableNo.21                   30
# AmitSahniKiList              30
# RajdhaniExpress              30
# BobbyJasoos                  30
#                              ..
# DumLagaKeHaisha              30
# NH10                         30
# DilliwaliZaalimGirlfriend    32
# Hunterrr                     30
# Kochadaiiyaan                50
# Name: BudgetList, Length: 149, dtype: int64

# %%
# drop_duplicates
temp=pd.Series([1,2,1,2,3,4,5,5,3,4])
temp.drop_duplicates(keep='last')#it will take the last occur
# Out:
# 2    1
# 3    2
# 7    5
# 8    3
# 9    4
# dtype: int64

# %%
subs.drop_duplicates().shape[0]
# Out:
# 49

# %%
temp=pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
# size and count
temp.size#with missing value
# Out:
# 10

# %%
temp.count()#without missing value
# Out:
# np.int64(7)

# %%
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
subs[(subs == 30) | (subs == 20)]
# Out:
# Daawat-E-Ishq             30
# KaiPoChe!                 30
# Highway                   30
# HumptySharmaKiDulhania    20
# TheAttacksof26/11         30
# ChashmeBaddoor            20
# Aurangzeb                 20
# Zid                       20
# Ghanchakkar               30
# Policegiri                30
# BhaagMilkhaBhaag          30
# DDay                      30
# GoriTerePyaarMein         30
# Name: BudgetList, dtype: int64

# %%
subs[subs.isin([20,30,22,36])]
# Out:
# 2States                   36
# Daawat-E-Ishq             30
# KaiPoChe!                 30
# Highway                   30
# ZillaGhaziabad            36
# HumptySharmaKiDulhania    20
# TheAttacksof26/11         30
# ChashmeBaddoor            20
# Commando-AOneManArmy      22
# Aurangzeb                 20
# Zid                       20
# Ghanchakkar               30
# Policegiri                30
# BhaagMilkhaBhaag          30
# Bewakoofiyan              22
# DDay                      30
# GoriTerePyaarMein         30
# Name: BudgetList, dtype: int64

# %%
# apply
# movies.apply(lambda x:x.split()[0]).upper() it will make all the leeter of the first word in capital letters

# %%
subs.apply(lambda x: "Good Collection" if x>subs.mean() else 'Bad Collection')
# Out:
# 2States                      Good Collection
# TableNo.21                    Bad Collection
# AmitSahniKiList               Bad Collection
# RajdhaniExpress               Bad Collection
# BobbyJasoos                   Bad Collection
#                                   ...
# DumLagaKeHaisha               Bad Collection
# NH10                          Bad Collection
# DilliwaliZaalimGirlfriend    Good Collection
# Hunterrr                      Bad Collection
# Kochadaiiyaan                Good Collection
# Name: BudgetList, Length: 149, dtype: object

# %%
# copy
new= subs.head()
new
# Out:
# 2States            36
# TableNo.21          1
# AmitSahniKiList    10
# RajdhaniExpress     7
# BobbyJasoos        18
# Name: BudgetList, dtype: int64

# %%
new[1]=1#it will make changes in the original pandas series
# Out:
# /tmp/ipython-input-3348571978.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new[1]=1

# %%
new=subs.head().copy()

# %%
new[1]=100#yaha pe change nhi hoga
# Out:
# /tmp/ipython-input-1038989606.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   new[1]=100

# %%
new
# Out:
# 2States             36
# TableNo.21         100
# AmitSahniKiList     10
# RajdhaniExpress      7
# BobbyJasoos         18
# Name: BudgetList, dtype: int64
