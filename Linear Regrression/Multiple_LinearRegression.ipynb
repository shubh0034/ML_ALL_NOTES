,-1.5235960823576078,0.7168994677369276,-0.4768779034262069,0.8179097073085495,-0.03557910704513694,0.11483856074426882,0.07357554123561938,1.1804700798231158,-1.1796094778872883,-0.21371229969359343,0.4199602637018201,-0.35181992513660104,-1.135425453590771,0.40464788624574644,-0.5672302186909215,-0.31663321721395277,-0.23131989734542052,0.19890862534461015,-1.0219000947620664,0.0795316307598023,0.23613869685180053,1.179440350772583,0.05492252311572058,-1.4804791146277554,1.4546258321509973,0.8713276087344685,-1.4311481444724088,-1.8885076251125554,-0.967515783758671,0.18500487793802903,2.54757564856412,-0.8112615992302122,-1.235993495245164,0.07783809577857058,0.41216707714389494,-0.4109962122187854,0.3908260392004445,-1.2705389235405251,-1.340584001828692,-0.08513848284529137,0.012560014626762829,-2.4157803688364665,0.3742389280666939,-0.08196147071048268,1.230496758189789,-1.1526599359015228,-0.08674377032008254,-1.3606342469606998,-1.1370475359850891,-0.08435050898120108,1.4918887819544355,1.0954259887822644,0.47726421415084413,-1.1966742701 ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("R2 Score",r2_score(y_test,y_pred))
# Out:
# MAE 52.176456430012834
# MSE 4181.806812885508
# RMSE 64.66689116453263
# R2 Score 0.7306448728940713

# %%
lr.coef_
# Out:
# array([101.4206132 ,  58.42946809])

# %%
lr.intercept_
# Out:
# np.float64(1.5827184169200805)

# %% [markdown]
# # **Self Made model for MLR**

# %%
from sklearn.datasets import load_diabetes

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
x.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
x_test.shape
# Out:
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4161792211496943

# %%
lr.coef_
# Out:
# array([  -1.13744712, -212.8867836 ,  540.45536994,  345.20621542,
#        -938.23814645,  516.62060367,  172.85885498,  267.87535242,
#         732.63230159,   70.07849485])

# %%
lr.intercept_
# Out:
# np.float64(153.13441535285003)

# %%
# khud ka MLR ka code
class MeraMLR:
  def __init__(self):
    self.coef_=None
    self.intercept_=None

  def fit(self,x_train,y_train):
    x_train=np.insert(x_train,0,1,axis=1)
    betas=np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)
    self.intercept_=betas[0]
    self.coef_=betas[1:]

  def predict(self,x_test):
    y_pred=np.dot(x_test,self.coef_)+self.intercept_
    return y_pred

# %%
lr=MeraMLR()

# %%
lr.fit(x_train,y_train)

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4161792211496943
